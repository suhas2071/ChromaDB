# %%
# !pip install --upgrade --quiet  langchain langchain_openai langchain-community langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
# !uname
# Out:
# Linux

# %% [markdown]
# !pip install -U \
# langchain \
# langchain-community \
# langchain-openai \
# langchain-chroma \
# langchain-text-splitters \
# chromadb

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR OPEN AI KEY"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage,ToolMessage

chat_llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0.7) # Recommended model for general use

promtsinfo = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the capital of France?"),
]

response = chat_llm.invoke(promtsinfo)
print(response.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# 🔹 Step 1: Message Creation
#
#
# SystemMessage
#
# Defines behavior
# 👉"You are a helpful assistant"
#
#
#
# HumanMessage
#
# User input
# 👉"What is the capital of France?"
#
#
#
# ✅ These messages form a conversation list
# 👉 Important:
#  Context for the model

# %% [markdown]
# Step 2: LangChain Interface
# PythonChatOpenAI(...)Show more lines
# 👉 Acts as:
#
# Wrapper around OpenAI API
# Standard interface
# Handles request formatting

# %% [markdown]
# Step 3: Invoke Call
# Python chat_llm.invoke(messages)Show more lines
# 👉 What happens internally:
#
# Converts LangChain messages → OpenAI format
# Sends request to GPT model
# Waits for response

# %% [markdown]
#  Step 4: LLM Processing
# Model:
# 👉 GPT-4o-mini
# Internally:
#
# Reads system instruction first
# Reads user question
# Applies reasoning
#
# 👉 Based on chat API design, roles guide behavior:
#
# system → instructions
# user → query
# assistant → response

# %% [markdown]
# Step 5: Response Returned
# Python response.content Show more lines
# 👉 Example:
# "The capital of France is Paris."

# %% [markdown]
# **LangChain structures the conversation, ChatOpenAI sends it to the model,
# and the LLM generates a response based on system instructions and user input.**

# %%
# Example with a follow-up
promtsinfo.append(AIMessage(content=response.content)) # Add AI's response to history
promtsinfo.append(HumanMessage(content="And what is its most famous landmark?"))
print(promtsinfo)
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='And what is its most famous landmark?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# Step 2: Add AI response to history
# promtsinfo.append(AIMessage(content=response.content))
# ✅ Now conversation becomes:
# Plain TextSystem → "You are helpful" User → "What is capital of France?"
# AI → "Paris"

# %% [markdown]
# Step 3: Add follow-up user question
# promtsinfo.append(HumanMessage(content="And what is its most famous landmark?"))
# ✅ Updated conversation:
# System → Instruction
# User → First Question
# AI → First Answer
# User → Follow-up Question ✅

# %%
follow_up_response = chat_llm.invoke(promtsinfo)
print(follow_up_response.content)
# Out:
# The most famous landmark in Paris is the Eiffel Tower.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage,ToolMessage

# It's highly recommended to use model_name="gpt-3.5-turbo" or "gpt-4" or "gpt-4o"
chat_llm = ChatOpenAI(model_name="gpt-5-mini", temperature=0.7) # Recommended model for general use

messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the capital of France?"),
]

response = chat_llm.invoke(messages)
print(response.content)
# Out:
# The capital of France is Paris.

# %%
# Example with a follow-up
messages.append(AIMessage(content=response.content)) # Add AI's response to history
messages.append(HumanMessage(content="And what is its most famous landmark?"))
print(messages)
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='And what is its most famous landmark?', additional_kwargs={}, response_metadata={})]

# %%
follow_up_response = chat_llm.invoke(messages)
print(follow_up_response.content)
# Out:
# Paris's most famous landmark is the Eiffel Tower.
# Built for the 1889 Exposition, it’s an iconic symbol of the city — though Paris is also well known for Notre-Dame, the Louvre, Arc de Triomphe, and Sacré‑Cœur.

# %%
# First, ensure you have langchain-openai installed:
# pip install langchain-openai

# Import the ChatOpenAI model
from langchain_openai import ChatOpenAI

# Import the specific message types and chat prompt template
#from langchain.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage


# 1. Define the AI's role and instructions using SystemMessage.
#    You create a list of messages.
#    The first message is typically a SystemMessage to set the persona.
#    Then, a HumanMessage for the actual user query.

# Instead of PromptTemplate.from_template, you often build a list of messages directly
# or use ChatPromptTemplate for more complex prompt engineering.
# For this simple case, we'll build the list of messages directly.

# System message to set the persona and tone
system_message_content = """
You are a friendly car mechanic. Answer the question below in simple terms.
Do not use technical words, give easy-to-understand responses in bullet format.
"""
system_message = SystemMessage(content=system_message_content.strip())


# Human message for the user's question
human_question = HumanMessage(content="Why won't my car start?")


# Combine them into a list of messages
messages_for_llm = [
    system_message,
    human_question
]

# 2. Ask the AI the question and get the answer.
#    Use .invoke() for a single turn, or .stream() for streaming responses.

# *** FIX: Explicitly instantiate ChatOpenAI here ***
# Use a different variable name or reassign llm if you intend to use ChatOpenAI
chat_llm_instance = ChatOpenAI(model="gpt-4o-mini", temperature=0.7) # Using a different variable name to avoid confusion

print("--- Sending message to LLM ---")
# *** FIX: Use the ChatOpenAI instance's invoke method ***
answer_message = chat_llm_instance.invoke(messages_for_llm)

# 3. Show the answer.
#    The response from ChatOpenAI's invoke is an AIMessage object,
#    so you access its content attribute.
print("\n--- AI's Answer ---")
print(answer_message.content) # This will now work as answer_message is an AIMessage object

# --- Example of a follow-up turn (showing memory concept in action) ---
# In a real conversation, you'd save the history.
messages_for_llm.append(answer_message) # Add AI's previous answer
follow_up_human_message = HumanMessage(content="What should I check first for a dead battery?")
messages_for_llm.append(follow_up_human_message)
# *** FIX: Use the ChatOpenAI instance's invoke method for the follow-up ***
follow_up_answer_message = chat_llm_instance.invoke(messages_for_llm)
print("\n--- Follow-up Answer ---")
print(follow_up_answer_message.content) # This will also work
# Out:
# --- Sending message to LLM ---
#
# --- AI's Answer ---
# There could be several reasons why your car won't start. Here are some common ones:
#
# - **Dead Battery**: The battery might be out of power. This can happen if lights were left on.
# - **Bad Starter**: The starter helps turn the engine on. If it’s not working, the car won't start.
# - **Fuel Issues**: The car might be low on gas or there could be a problem with the fuel getting to the engine.
# - **Ignition Problems**: The key or the ignition system might not be working properly.
# - **Faulty Alternator**: The alternator helps charge the battery while the car runs. If it’s not working, the battery can die.
# - **Wiring Issues**: There could be loose or damaged wires that prevent the car from starting.
# - **Security System**: Sometimes, the car’s security system can prevent it from starting if it thinks there’s a problem.
#
# If your car won't start, it’s best to have a mechanic check it out.
#
# --- Follow-up Answer ---
# If you think your car's battery might be dead, here are some easy steps to check first:
#
# - **Check the Lights**: Turn on the headlights. If they are dim or don’t turn on, the battery may be dead.
# - **Listen for Sounds**: When you turn the key, listen for a clicking sound. If you hear it, the battery could be weak.
# - **Look for Dashboard Lights**: When you try to start the car, see if the dashboard lights come on. If they don’t, the battery might be the issue.
# - **Check Battery Connections**: Open the hood and look at the battery. Make sure the cables are tight and not corroded (look for white or green stuff around the connections).
# - **Try Jumpstarting**: If you have jumper cables and another working car, you can try to jumpstart it. If it starts, the battery was likely dead.
#
# If these steps don’t help, it might be best to call a mechanic for further help.

# %%
# First, ensure you have langchain-openai installed:
# pip install langchain-openai

# Import the ChatOpenAI model
from langchain_openai import ChatOpenAI

# Import the specific message types and chat prompt template
#from langchain.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage


# 1. Define the AI's role and instructions using SystemMessage.
#    You create a list of messages.
#    The first message is typically a SystemMessage to set the persona.
#    Then, a HumanMessage for the actual user query.

# Instead of PromptTemplate.from_template, you often build a list of messages directly
# or use ChatPromptTemplate for more complex prompt engineering.
# For this simple case, we'll build the list of messages directly.

# System message to set the persona and tone
system_message_content = """
You are a friendly doctor. Please answer the question below using simple words.
Do not use technical words, give easy/
to understand responses in bullet format
"""
system_message = SystemMessage(content=system_message_content.strip())


# Human message for the user's question
human_question = HumanMessage(content="How to control Diabetes without taking medicine?")


# Combine them into a list of messages
messages_for_llm = [
    system_message,
    human_question
]

# 2. Ask the AI the question and get the answer.
#    Use .invoke() for a single turn, or .stream() for streaming responses.

# *** FIX: Explicitly instantiate ChatOpenAI here ***
# Use a different variable name or reassign llm if you intend to use ChatOpenAI
chat_llm_instance = ChatOpenAI(model="gpt-4o-mini", temperature=0.7) # Using a different variable name to avoid confusion

print("--- Sending message to LLM ---")
# *** FIX: Use the ChatOpenAI instance's invoke method ***
answer_message = chat_llm_instance.invoke(messages_for_llm)

# 3. Show the answer.
#    The response from ChatOpenAI's invoke is an AIMessage object,
#    so you access its content attribute.
print("\n--- AI's Answer ---")
print(answer_message.content) # This will now work as answer_message is an AIMessage object

# --- Example of a follow-up turn (showing memory concept in action) ---
# In a real conversation, you'd save the history.
messages_for_llm.append(answer_message) # Add AI's previous answer
follow_up_human_message = HumanMessage(content="How much quantity to Limit Alcohol")
messages_for_llm.append(follow_up_human_message)
# *** FIX: Use the ChatOpenAI instance's invoke method for the follow-up ***
follow_up_answer_message = chat_llm_instance.invoke(messages_for_llm)
print("\n--- Follow-up Answer ---")
print(follow_up_answer_message.content) # This will also work
# Out:
# --- Sending message to LLM ---
#
# --- AI's Answer ---
# Sure! Here are some simple ways to help control diabetes without medicine:
#
# - **Eat Healthy Foods**: Focus on fruits, vegetables, whole grains, and lean proteins. These foods help keep your blood sugar stable.
#
# - **Watch Portion Sizes**: Don't eat too much at once. Smaller meals can help manage blood sugar levels.
#
# - **Stay Active**: Try to exercise regularly, like walking, biking, or dancing. Aim for at least 30 minutes most days.
#
# - **Drink Water**: Stay hydrated by drinking plenty of water instead of sugary drinks.
#
# - **Limit Sugar and Refined Carbs**: Cut back on sweets, white bread, and pasta. These can spike your blood sugar.
#
# - **Monitor Blood Sugar**: Check your blood sugar levels often to see how food and activities affect them.
#
# - **Manage Stress**: Find ways to relax, like deep breathing, yoga, or spending time with friends. Stress can affect blood sugar levels.
#
# - **Get Enough Sleep**: Aim for 7-9 hours of good sleep each night. Lack of sleep can make blood sugar harder to control.
#
# - **Stay Consistent**: Try to eat and exercise at the same times each day. Routine helps keep your blood sugar steady.
#
# Always talk to your doctor before making big changes to your diet or exercise!
#
# --- Follow-up Answer ---
# Here are some simple guidelines on how much alcohol to limit:
#
# - **For Men**: Up to 2 drinks per day.
# - **For Women**: Up to 1 drink per day.
#
# **What counts as one drink?**
# - **Beer**: 12 ounces (about a small bottle or can)
# - **Wine**: 5 ounces (about a small glass)
# - **Spirits**: 1.5 ounces (like a shot of whiskey or vodka)
#
# **Tips**:
# - Drink slowly and enjoy your drink.
# - Choose low-sugar drinks when possible.
# - Always eat something while drinking to help balance your blood sugar.
#
# Remember, it's best to talk to your doctor about what’s right for you, especially if you have diabetes!

# %%
# First, ensure you have langchain-openai installed:
# pip install langchain-openai

# Import the ChatOpenAI model
from langchain_openai import ChatOpenAI

# Import the specific message types and chat prompt template
#from langchain.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage


# 1. Define the AI's role and instructions using SystemMessage.
#    You create a list of messages.
#    The first message is typically a SystemMessage to set the persona.
#    Then, a HumanMessage for the actual user query.

# Instead of PromptTemplate.from_template, you often build a list of messages directly
# or use ChatPromptTemplate for more complex prompt engineering.
# For this simple case, we'll build the list of messages directly.

# System message to set the persona and tone
system_message_content = """
You are a AWS Solution Architect, give responses to the following/
question: {question}. Do not use complex words, give easy/
to understand responses.Do not use technical words, give easy/
to understand responses in bullet format
"""
system_message = SystemMessage(content=system_message_content.strip())


# Human message for the user's question
human_question = HumanMessage(content="You are an expert AWS Solution architect. Company wants to move 5 PB of data from on premise servers to AWS Cloud Environment. Company is not having any direct connection to transfer data. I need device you can send to our company. we will transfer 5PB of data to device and later we can upload to nearest region. Our company is based in Bengaluru location. after transfering 5PB of data to aws S3 service. 4PB of data should be kept for a period of 5- 7years. provide me cost effective solution for the same.?")


# Combine them into a list of messages
messages_for_llm = [
    system_message,
    human_question
]

# 2. Ask the AI the question and get the answer.
#    Use .invoke() for a single turn, or .stream() for streaming responses.

# *** FIX: Explicitly instantiate ChatOpenAI here ***
# Use a different variable name or reassign llm if you intend to use ChatOpenAI
chat_llm_instance = ChatOpenAI(model="gpt-4o-mini", temperature=0.7) # Using a different variable name to avoid confusion

print("--- Sending message to LLM ---")
# *** FIX: Use the ChatOpenAI instance's invoke method ***
answer_message = chat_llm_instance.invoke(messages_for_llm)

# 3. Show the answer.
#    The response from ChatOpenAI's invoke is an AIMessage object,
#    so you access its content attribute.
print("\n--- AI's Answer ---")
print(answer_message.content) # This will now work as answer_message is an AIMessage object

# --- Example of a follow-up turn (showing memory concept in action) ---
# In a real conversation, you'd save the history.
messages_for_llm.append(answer_message) # Add AI's previous answer
follow_up_human_message = HumanMessage(content="How to purshase The Snowball device")
messages_for_llm.append(follow_up_human_message)
# *** FIX: Use the ChatOpenAI instance's invoke method for the follow-up ***
follow_up_answer_message = chat_llm_instance.invoke(messages_for_llm)
print("\n--- Follow-up Answer ---")
print(follow_up_answer_message.content) # This will also work
# Out:
# --- Sending message to LLM ---
#
# --- AI's Answer ---
# Here’s a simple plan to move your 5 PB of data to AWS and store it cost-effectively:
#
# ### 1. Use AWS Snowball
# - **What is it?** A physical device that helps you transfer large amounts of data to AWS.
# - **How it works:** You request the device, fill it with your data, and then send it back to AWS.
# - **Capacity:** Each Snowball device can hold up to 80 TB. You will need about 63 devices for 5 PB.
#
# ### 2. Transfer Process
# - **Request Devices:** Order the Snowball devices from AWS.
# - **Data Transfer:** Fill each device with your 5 PB of data.
# - **Return Devices:** Send the filled devices back to AWS.
#
# ### 3. Upload to Amazon S3
# - **Where to Store:** Once AWS receives the devices, they will upload your data to Amazon S3 (Simple Storage Service).
# - **Storage Class:** Use Amazon S3 Glacier for the 4 PB that you want to keep for 5-7 years. It’s cheaper for long-term storage.
#
# ### 4. Cost Considerations
# - **Snowball Costs:** There is a charge for using the Snowball device, including shipping fees.
# - **Data Transfer Cost:** You won’t be charged for data transfer into S3.
# - **Storage Costs:** S3 Glacier is very affordable for long-term storage.
#
# ### 5. Additional Tips
# - **Plan for Access:** If you need to access the data, Glacier has options for quicker retrieval, but it will cost more.
# - **Regular Checks:** Monitor your storage to ensure it stays within budget over the years.
#
# By using AWS Snowball and S3 Glacier, you can transfer your data efficiently and save money on long-term storage.
#
# --- Follow-up Answer ---
# Here’s how you can purchase the AWS Snowball device:
#
# ### 1. Sign in to AWS
# - **Go to AWS:** Visit the AWS Management Console.
# - **Log in:** Use your AWS account credentials to sign in.
#
# ### 2. Access AWS Snow Family
# - **Navigate to Snow Family:** In the AWS Management Console, search for “Snow Family” in the services search bar.
#
# ### 3. Create a Job
# - **Create a Job:** Click on “Create job” to start the process.
# - **Select Snowball:** Choose the Snowball option for data transfer.
#
# ### 4. Configure the Job
# - **Select Capacity:** Choose the type of Snowball device you need (80 TB or 42 TB).
# - **Specify Data:** Indicate the amount of data you plan to transfer (5 PB).
# - **Choose Options:** You can customize options like encryption and notifications.
#
# ### 5. Review and Confirm
# - **Review Details:** Check that all the information is correct.
# - **Confirm Order:** Click “Create job” to finalize your request for the Snowball device.
#
# ### 6. Wait for Delivery
# - **Receive Device:** AWS will ship the Snowball device to your specified address.
# - **Transfer Data:** Once you receive it, fill it with your data.
#
# ### 7. Return the Device
# - **Send Back:** After transferring your data, send the device back to AWS using the provided shipping instructions.
#
# ### Additional Notes
# - **Cost:** Be aware of the costs associated with using Snowball, which may include rental fees and shipping charges.
# - **Support:** If you need help during the process, you can contact AWS Support for assistance.
#
# By following these steps, you can successfully purchase and use the Snowball device for your data transfer.

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.136.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.19.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.32)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.17)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.49.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.18)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.29.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %% [markdown]
#  1. Import Gradio
# import gradio as gr
# 👉 Purpose:
# Creates a web UI (front-end) for your app
# Converts your Python function into a web chatbot
#
# ✅ Output:
#
# Browser-based interface

# %% [markdown]
#  2. Import ChatOpenAI
# from langchain_openai import ChatOpenAI
# 👉 Purpose:
#
# Connects to OpenAI Chat Models (GPT)
# Acts as wrapper for API
#
# ✅ Example:
# gpt-4o, gpt-4o-mini

# %% [markdown]
# 3. Import Prompt Template
#
# from langchain_core.prompts import ChatPromptTemplate
# 👉 Purpose:
#
# Defines how input is formatted before sending to LLM
#
# ✅ Converts:
# User question → structured prompt → model input

# %% [markdown]
# 4. Import Output Parser
#
# from langchain_core.output_parsers import StrOutputParser
#
# 👉 Purpose:
#
# Converts model output into plain string
#
# ✅ Why needed:
#
# LLM returns structured object → parser extracts text

# %% [markdown]
#  5. Define Main Function
#
# def generate_aws_solution(user_question):
# 👉 Purpose:
#
# This function:
#
# Takes user input
# Processes it
# Returns response
#
#
#
# ✅ This is your backend logic

# %% [markdown]
#  6. Define Prompt Template
#
# prompt = ChatPromptTemplate.from_template("""You are an AWS expert...Question:{question}""")
#
# 👉 Purpose:
# Creates a dynamic prompt template
# ✅ Important:
# {question} → placeholder
# 👉 Example output:
# You are an AWS expert...
# Question: How to design scalable system?

# %% [markdown]
#  7. Initialize LLM
# llm = ChatOpenAI(model="gpt-4o-mini",  temperature=0.7)
# 👉 Purpose:
#
# Connects to OpenAI model
#
# ✅ Parameters:
#
#
# Parameter Meaning model Which GPT to use temperature Creativity level

# %% [markdown]
#  Temperature explained:
#
# 0 → deterministic (same output)
# 0.7 → balanced (good for chatbot ✅)
# 1+ → creative (more variation)

# %% [markdown]
# 8. Create Output Parser
# parser = StrOutputParser()
#
# 👉 Purpose:
#
# Extracts:
#
# AIMessage → string
#
# 👉 Example:
# AIMessage(content="Use S3 for storage...")
# → "Use S3 for storage..."

# %% [markdown]
#  9. Create Chain (MOST IMPORTANT)
# chain = prompt | llm | parser
#
# 👉 This is LCEL (LangChain Expression Language)
#
# 🧠 Meaning:
# Prompt → LLM → Output Parser
#
# ✅ Data Flow:
# Input →
# PromptTemplate →
# LLM →
# Parser →
# Final Output

# %% [markdown]
# User Question (Gradio UI)
#         ↓
# generate_aws_solution()
#         ↓
# Prompt Template
#         ↓
# ChatOpenAI (LLM)
#         ↓
# Output Parser
#         ↓
# Return Result
#         ↓
# Displayed on UI

# %%
import gradio as gr

# ✅ Modern LangChain imports
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


# ✅ Function
def generate_aws_solution(user_question):
    """Generates an AWS solution using modern LangChain pipeline"""

    # 1️⃣ Prompt Template (UPDATED ✅)
    prompt = ChatPromptTemplate.from_template("""
You are an AWS expert. Answer the question below in simple terms using bullet points.

Question:
{question}
""")

    # 2️⃣ LLM (UPDATED ✅)
    llm = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0.7
    )

    # 3️⃣ Output parser (REQUIRED in LCEL ✅)
    parser = StrOutputParser()

    # 4️⃣ Chain (LCEL PIPELINE ✅)
    chain = prompt | llm | parser

    # 5️⃣ Invoke
    response = chain.invoke({"question": user_question})

    return response


# ✅ Gradio UI
iface = gr.Interface(
    fn=generate_aws_solution,
    inputs=gr.Textbox(
        lines=5,
        placeholder="Enter your AWS question here..."
    ),
    outputs=gr.Textbox(
        lines=10,
        placeholder="AWS Solution will appear here..."
    ),
    title="AWS Solution Architect Chatbot",
    description="Ask AWS questions and get simple bullet-point solutions."
)

iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9309dfbcb3ccf1c90d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9309dfbcb3ccf1c90d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
